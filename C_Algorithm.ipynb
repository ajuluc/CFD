# %%
import sys
sys.path.append('/Users/ebubeajulu/anaconda3/envs/rmg_py3')

# %%
# !which python 
# !conda list rmg
# Out:
# /Users/ebubeajulu/anaconda3/envs/rmg_py3/bin/python
# # packages in environment at /Users/ebubeajulu/anaconda3/envs/rmg_py3:
# #
# # Name                    Version                   Build  Channel

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

from matplotlib import pyplot as plt

plt.style.use('classic')
plt.rcParams['figure.autolayout'] = True

# %%
# algo_data_moves = [252149, 0, 499500, 540939, 2997, 7500, 27207, 29124, 24948]

algorithm_data = {
    'InsertSort': {
        'moves':[['Average', 'Best', 'Worst'],[252149, 0, 499500]],
        'comps':[['Average', 'Best', 'Worst'], [999, 999, 999]]
            }, 
    'QuickSort': {
        'moves':[['Average', 'Best', 'Worst'],[540939, 2997, 7500]],
        'comps':[['Average', 'Best', 'Worst'], [181581, 499500, 2500]]
            } ,
    'HeapSort': {
        'moves':[['Average', 'Best', 'Worst'],[27207, 29124, 24948]],
        'comps':[['Average', 'Best', 'Worst'], [19138, 20416, 17632]]
    } 
    
}

a = np.array(algorithm_data['InsertSort']['moves'][1])
a
a.T
# algo_data_comps = [999, 999, 999, 181581, 499500, 2500, 19138 20416, 17632]
# Out:
# array([252149,      0, 499500])

# %%
algorithm_data

pdObj = pd.DataFrame(algorithm_data)
pdObj
# Out:
#                                           InsertSort  \
# moves  [[Average, Best, Worst], [252149, 0, 499500]]
# comps      [[Average, Best, Worst], [999, 999, 999]]
#
#                                               QuickSort  \
# moves    [[Average, Best, Worst], [540939, 2997, 7500]]
# comps  [[Average, Best, Worst], [181581, 499500, 2500]]
#
#                                               HeapSort
# moves  [[Average, Best, Worst], [27207, 29124, 24948]]
# comps  [[Average, Best, Worst], [19138, 20416, 17632]]

# %%
pdObj['HeapSort'].iloc[1][1]
# Out:
# [19138, 20416, 17632]

# %%
tranpose1 = pdObj['InsertSort'].iloc[0][1]
tranpose2 = pdObj['InsertSort'].iloc[1][1]

names = pdObj['InsertSort'].iloc[0][0]
plt.barh(names,tranpose1)
plt.barh(names,tranpose2)
plt.title('InsertSort Algorithm')


plt.gca().invert_yaxis()
# plt.rcParams.update({'axes.labelsize': 20})
# plt.xlabel(r'Number of Times Moves occurs')
plt.grid(False)
# plt.style.use('classic')
# plt.legend(["700K", "900K", "1300K"], loc="best")
plt.rcParams['figure.figsize'] = [10, 8]
plt.show()

# %%
firstColumn = pdObj.columns[0]
secondColumn = pdObj.columns[1]
thirdColumn = pdObj.columns[2]

threshold = 0

for subset in pdObj.columns:
    i = 0; j = 1
#     algorithm_dataSubset = pdObj[pdObj[subset][i][j].abs() >= threshold]
#     indicesMeetingThreshold = pdObj[subset][i][j].sort_values(ascending=False).index
    plt.barh(pdObj[subset].iloc[i][i],pdObj[subset].iloc[i][j]) 

# pdObj['InsertSort']['moves'][1].plot.barh(title="InsertSort Algorithms", legend=True)
plt.legend(["InsertSort", "QuickSort", "HeapSort"],loc="best")
plt.title("Moves Algorithm")
plt.show()
# plt.gca().invert_yaxis()
# plt.rcParams.update({'axes.labelsize': 20})
# plt.xlabel(r'Number of Times Moves occurs')
# plt.grid(False)
# # plt.style.use('classic')
# # plt.legend(["700K", "900K", "1300K"], loc="best")
# plt.rcParams['figure.figsize'] = [10, 8]

# %%
firstColumn = pdObj.columns[0]
secondColumn = pdObj.columns[1]
thirdColumn = pdObj.columns[2]

threshold = 0

for subset in pdObj.columns:
    i = 0; j = 1
#     algorithm_dataSubset = pdObj[pdObj[subset][i][j].abs() >= threshold]
#     indicesMeetingThreshold = pdObj[subset][i][j].sort_values(ascending=False).index
    plt.barh(width=0.2,pdObj[subset].iloc[j][i],pdObj[subset].iloc[j][j]) 

# pdObj['InsertSort']['moves'][1].plot.barh(title="InsertSort Algorithms", legend=True)
plt.legend(["InsertSort", "QuickSort", "HeapSort"],loc="best")
plt.title("Comps Algorithm")
plt.show()
# plt.gca().invert_yaxis()
# plt.rcParams.update({'axes.labelsize': 20})
# plt.xlabel(r'Number of Times Moves occurs')
# plt.grid(False)
# # plt.style.use('classic')
# # plt.legend(["700K", "900K", "1300K"], loc="best")
# plt.rcParams['figure.figsize'] = [10, 8]
# Out:
#   File "<ipython-input-158-48a2b85b581e>", line 11
#     plt.barh(width=0.2,pdObj[subset].iloc[j][i],pdObj[subset].iloc[j][j])
#                       ^
# SyntaxError: positional argument follows keyword argument

# %%
algorithm_data['InsertSort']
# Out:
# {'moves': [['Average', 'Best', 'Worst'], [252149, 0, 499500]],
#  'comps': [['Average', 'Best', 'Worst'], [999, 999, 999]]}

# %%
for
